# %%
from openai import OpenAI
from dotenv import load_dotenv
import os
from pypdf import PdfReader
import gradio as gr

# %%
load_dotenv(override=True)
# Out:
# True

# %%
reader = PdfReader('Profile.pdf')    
type(reader)
# Out:
# pypdf._reader.PdfReader

# %%
openai = OpenAI(
    api_key=os.getenv("OPEN_AI_KEY")
)
linkedIn = ""
for reader in reader.pages:
    text = reader.extract_text()
    if text:
        linkedIn  += text

# %%
with open("MyInfo.txt", "r", encoding="utf-8") as file:
    summary = file.read()

# %%
summary
# Out:
# 'My name is Subhash Onathara, I live in Pune, and I am fond of technolgy. I am also passionate about reading, watching movie and watching Cricket. I love programming in Python, studying in Data Science, and I am also passionte about self development.'

# %%
name = "Subhash Onathara"

# %%
system_prompt = f"You are acting as {name}. You are answering questions on {name}'s website, \
particularly questions related to {name}'s career, background, skills and experience. \
Your responsibility is to represent {name} for interactions on the website as faithfully as possible. \
You are given a summary of {name}'s background and LinkedIn profile which you can use to answer questions. \
Be professional and engaging, as if talking to a potential client or future employer who came across the website. \
If you don't know the answer, say so."

system_prompt += f"\n\n## Summary:\n{summary}\n\n## LinkedIn Profile:\n{linkedIn}\n\n"
system_prompt += f"With this context, please chat with the user, always staying in character as {name}."

# %%
def chat(message, history):
    # Build messages list starting with system prompt
    messages = [{"role": "system", "content": system_prompt}]+ history + [{"role": "user", "content": message}]
        
    # Get response from OpenAI
    response = openai.chat.completions.create(
        model="gpt-4o-mini",
        messages=messages
    )
    return response.choices[0].message.content

# %%
system_prompt
# Out:
# "You are acting as Subhash Onathara. You are answering questions on Subhash Onathara's website, particularly questions related to Subhash Onathara's career, background, skills and experience. Your responsibility is to represent Subhash Onathara for interactions on the website as faithfully as possible. You are given a summary of Subhash Onathara's background and LinkedIn profile which you can use to answer questions. Be professional and engaging, as if talking to a potential client or future employer who came across the website. If you don't know the answer, say so.\n\n## Summary:\nMy name is Subhash Onathara, I live in Pune, and I am fond of technolgy. I am also passionate about reading, watching movie and watching Cricket. I love programming in Python, studying in Data Science, and I am also passionte about self development.\n\n## LinkedIn Profile:\n\xa0 \xa0\nContact\nsubhash.onathara@gmail.com\nwww.linkedin.com/in/subhash-\nonathara-6a293526 (LinkedIn)\nTop Skills\nInventory Management\nBusiness Analysis\nSAP ERP\nCertifications\nFinancial Modeling\nSupply Chain Transformation - Level\n1\nTechnical Analysis in Financial\nMarket\nPublications\nBrick Click and Tricks - eCommerce\nin Indian Market\nSubhash Onathara\nSupply Chain Management / Enterprise Asset Management\nPune, Maharashtra, India\nSummary\nExperienced Manager with a demonstrated history of working\nin the information technology and services industry. Skilled\nin Business Process, Business Process Design, SAP ERP,\nBusiness Intelligence, and Business Process Improvement. Strong\nprofessional with a MBA focused in Operations from Symbiosis\nInstitute of Business Management. \nExperience\nGoogle\nSupply Chain Management, Inventory Management\nFebruary 2022\xa0-\xa0Present\xa0(4 years)\nMumbai, Maharashtra, India\nInventory Optimization\nSupply Chain Governance and Control\nParts Planning\nAccenture\nManager, Strategy Consulting\nJuly 2021\xa0-\xa0February 2022\xa0(8 months)\nPune, Maharashtra, India\nSysintelli Inc,\n3 years 1 month\nManager\nMay 2019\xa0-\xa0May 2021\xa0(2 years 1 month)\nPune Area, India\nSupply Chain Solution Manager expertise in Consulting and Technology\nAdoption\nSr Associate\nMay 2018\xa0-\xa0May 2019\xa0(1 year 1 month)\nGreater Atlanta Area\n\xa0 Page 1 of 3\xa0 \xa0\nBristlecone\nSr Consultant \nJune 2017\xa0-\xa0March 2018\xa0(10 months)\nPune Area, India\nDeloitte Consulting\nConsulting\nJune 2012\xa0-\xa0May 2017\xa0(5 years)\nMumbai Area, India\nIndustry:C&IP, Retail, and Manufacturing                                                        \nResponsibilities :\n• Digital Transformation of Supply Chain Management and Operations\n•       TCO Modelling, CMM Mapping, and FTE Analysis\n• Strategic Sourcing Project and Procurement Policies \n• End to End Process Mapping and Documentation of Procurement and\nOperational Process.\n• RFP Responses, Practice Building, Team Leading\n• Client Management, working with the CXO for clients\nTools :\n• Project Estimator and Planning Suite (PEPS Tool Deloitte)\n• ARIS – Process Modeler Architecture\n• Rapid Deployment Solutions (RDS – Proprietary tool for rapid\ntransformations)\n• SAP MM, SCM, Logistics.\n• Ariba, Concur, Coupa, and OpenText\n• Project Management / FTE / CMM / TCO Models\nJ L Morison\nSummer Trainee\n2011\xa0-\xa02011\xa0(less than a year)\neClerx Services Ltd\nAnalyst\nJune 2008\xa0-\xa0May 2009\xa0(1 year)\nPune\nEducation\nSymbiosis Institute of Business Management\nMBA,\xa0Operations\xa0·\xa0(2010\xa0-\xa02012)\n\xa0 Page 2 of 3\xa0 \xa0\nSymbiosis International University\nBachelor of Computer Science,\xa0Computer Science\xa0·\xa0(2005\xa0-\xa02008)\nUniversity of Pune\nBsc,\xa0Computer Science\xa0·\xa0(2005\xa0-\xa02008)\n\xa0 Page 3 of 3\n\nWith this context, please chat with the user, always staying in character as Subhash Onathara."

# %%
gr.ChatInterface(chat).launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7864
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7864/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
history
# Out:
# from openai import OpenAI
# from dotenv import load_dotenv
# import os
#
# import gradio as gr
# import PyPdf2
# from openai import OpenAI
# from dotenv import load_dotenv
# import os
# from pypdf import PdfReader
# import gradio as gr
# from openai import OpenAI
# from dotenv import load_dotenv
# import os
# from pypdf2 import PdfReader
# import gradio as gr
# from openai import OpenAI
# from dotenv import load_dotenv
# import os
# from pypdf3 import PdfReader
# import gradio as gr
# from openai import OpenAI
# from dotenv import load_dotenv
# import os
# from pypdf import PdfReader
# import gradio as gr
# load_dotenv(override=True)
# PdfReader('Practice2.pdf')
# PdfReader('Profile.pdf')
# reader = PdfReader('Profile.pdf')
# type(reader)
# reader.pages[0]
# for reader in reader.pages:
#     print(reader.extract_text())
# linked = ""
# for reader in reader.pages:
#     linked = linked + reader.extract_text()
# linkedIn = ""
# for reader in reader.pages:
#     text = reader.extract_text()
#     if text:
#         linkedIn = linkedIn + text
# linkedIn = ""
# for reader in reader.pages:
#     text = reader.extract_text()
#     if text:
#         linkedIn = linkedIn + text
# linkedIn = ""
# for reader in reader.pages:
#     text = reader.extract_text()
#     if text:
#         linkedIn linkedIn += text
# linkedIn = ""
# for reader in reader.pages:
#     text = reader.extract_text()
#     if text:
#         linkedIn  += text
# reader = PdfReader('Profile.pdf')
# type(reader)
# linkedIn = ""
# for reader in reader.pages:
#     text = reader.extract_text()
#     if text:
#         linkedIn  += text
# linkedIn
# print(linkedIn)
# with open("MyInfo.txt", "r", encoding="utf-8") as file:
#     summary = file.read()
# summary
# name = "Subhash Onathara"
# system_prompt = f"You are acting as {name}. You are answering questions on {name}'s website, \
# particularly questions related to {name}'s career, background, skills and experience. \
# Your responsibility is to represent {name} for interactions on the website as faithfully as possible. \
# You are given a summary of {name}'s background and LinkedIn profile which you can use to answer questions. \
# Be professional and engaging, as if talking to a potential client or future employer who came across the website. \
# If you don't know the answer, say so."
#
# system_prompt += f"\n\n## Summary:\n{summary}\n\n## LinkedIn Profile:\n{linkedin}\n\n"
# system_prompt += f"With this context, please chat with the user, always staying in character as {name}."
# system_prompt = f"You are acting as {name}. You are answering questions on {name}'s website, \
# particularly questions related to {name}'s career, background, skills and experience. \
# Your responsibility is to represent {name} for interactions on the website as faithfully as possible. \
# You are given a summary of {name}'s background and LinkedIn profile which you can use to answer questions. \
# Be professional and engaging, as if talking to a potential client or future employer who came across the website. \
# If you don't know the answer, say so."
#
# system_prompt += f"\n\n## Summary:\n{summary}\n\n## LinkedIn Profile:\n{linkedIn}\n\n"
# system_prompt += f"With this context, please chat with the user, always staying in character as {name}."
# def chat(message, history):
#     messages = [
#         {"role": "system", "content": system_prompt} + history +  {"role": "user", "content": message}
#     ]
#     response = openai.chat.completions.create(
#         model="gpt-4o-mini",
# def chat(message, history):
#     messages = [
#         {"role": "system", "content": system_prompt} + history +  {"role": "user", "content": message}
#     ]
#     response = openai.chat.completions.create(
#         model="gpt-4o-mini",
#         messages=messages
#     )
#     return response.choices[0].message.content
# system_prompt
# gr.ChatInterface(chat, type="messages").launch()
# gr.ChatInterface(chat).launch()
# gr.ChatInterface(chat).launch(share=True)
# from openai import OpenAI
# from dotenv import load_dotenv
# import os
# from pypdf import PdfReader
# import gradio as gr
#
# client = OpenAI()
# from openai import OpenAI
# from dotenv import load_dotenv
# import os
# from pypdf import PdfReader
# import gradio as gr
#
# client = OpenAI()
# load_dotenv(override=True)
# from openai import OpenAI
# from dotenv import load_dotenv
# import os
# from pypdf import PdfReader
# import gradio as gr
# reader = PdfReader('Profile.pdf')
# type(reader)
# openai = OpenAI(
#     api_key=os.getenv("OPEN_AI_KEY")
# )
# linkedIn = ""
# for reader in reader.pages:
#     text = reader.extract_text()
#     if text:
#         linkedIn  += text
# with open("MyInfo.txt", "r", encoding="utf-8") as file:
#     summary = file.read()
# summary
# name = "Subhash Onathara"
# system_prompt = f"You are acting as {name}. You are answering questions on {name}'s website, \
# particularly questions related to {name}'s career, background, skills and experience. \
# Your responsibility is to represent {name} for interactions on the website as faithfully as possible. \
# You are given a summary of {name}'s background and LinkedIn profile which you can use to answer questions. \
# Be professional and engaging, as if talking to a potential client or future employer who came across the website. \
# If you don't know the answer, say so."
#
# system_prompt += f"\n\n## Summary:\n{summary}\n\n## LinkedIn Profile:\n{linkedIn}\n\n"
# system_prompt += f"With this context, please chat with the user, always staying in character as {name}."
# system_prompt = f"You are acting as {name}. You are answering questions on {name}'s website, \
# particularly questions related to {name}'s career, background, skills and experience. \
# Your responsibility is to represent {name} for interactions on the website as faithfully as possible. \
# You are given a summary of {name}'s background and LinkedIn profile which you can use to answer questions. \
# Be professional and engaging, as if talking to a potential client or future employer who came across the website. \
# If you don't know the answer, say so."
#
# system_prompt += f"\n\n## Summary:\n{summary}\n\n## LinkedIn Profile:\n{linkedIn}\n\n"
# system_prompt += f"With this context, please chat with the user, always staying in character as {name}."
# def chat(message, history):
#     # Build messages list starting with system prompt
#     messages = [{"role": "system", "content": system_prompt}]
#
#     # Add conversation history (history is list of tuples: [(user_msg, assistant_msg), ...])
#     if history:
#         for user_msg, assistant_msg in history:
#             messages.append({"role": "user", "content": user_msg})
#             messages.append({"role": "assistant", "content": assistant_msg})
#
#     # Add current user message
#     messages.append({"role": "user", "content": message})
#
#     # Get response from OpenAI
#     response = client.chat.completions.create(
#         model="gpt-4o-mini",
#         messages=messages
#     )
#     return response.choices[0].message.content
# gr.ChatInterface(chat).launch()
# def chat(message, history):
#     # Build messages list starting with system prompt
#     messages = [{"role": "system", "content": system_prompt}]
#
#     # Add conversation history (history is list of tuples: [(user_msg, assistant_msg), ...])
#     if history:
#         for user_msg, assistant_msg in history:
#             messages.append({"role": "user", "content": user_msg})
#             messages.append({"role": "assistant", "content": assistant_msg})
#
#     # Add current user message
#     messages.append({"role": "user", "content": message})
#
#     # Get response from OpenAI
#     response = openai.chat.completions.create(
#         model="gpt-4o-mini",
#         messages=messages
#     )
#     return response.choices[0].message.content
# gr.ChatInterface(chat).launch()
# history
# def chat(message, history):
#     # Build messages list starting with system prompt
#     messages = [{"role": "system", "content": system_prompt}]+ history + [{"role": "user", "content": message}]
#
#     # Get response from OpenAI
#     response = openai.chat.completions.create(
#         model="gpt-4o-mini",
#         messages=messages
#     )
#     return response.choices[0].message.content
# gr.ChatInterface(chat).launch()
# history

# %%
from pydantic import BaseModel

# %%
class Evaluation(BaseModel):
    is_acceptable: bool
    feedback: str

# %%
evaluator_system_prompt = f"You are an evaluator that decides whether a response to a question is acceptable. \
You are provided with a conversation between a User and an Agent. Your task is to decide whether the Agent's latest response is acceptable quality. \
The Agent is playing the role of {name} and is representing {name} on their website. \
The Agent has been instructed to be professional and engaging, as if talking to a potential client or future employer who came across the website. \
The Agent has been provided with context on {name} in the form of their summary and LinkedIn details. Here's the information:"

evaluator_system_prompt += f"\n\n## Summary:\n{summary}\n\n## LinkedIn Profile:\n{linkedIn}\n\n"
evaluator_system_prompt += f"With this context, please evaluate the latest response, replying with whether the response is acceptable and your feedback."

# %%
def evaluator_user_prompt(reply, message, history):
    user_prompt = f"Here's the conversation between the User and the Agent: \n\n{history}\n\n"
    user_prompt += f"Here's the latest message from the User: \n\n{message}\n\n"
    user_prompt += f"Here's the latest response from the Agent: \n\n{reply}\n\n"
    user_prompt += "Please evaluate the response, replying with whether it is acceptable and your feedback."
    return user_prompt

# %%
import os
load_dotenv()
gemini = OpenAI(
    api_key=os.getenv("GOOGLE_GEMINI_KEY"), 
    base_url="https://generativelanguage.googleapis.com/v1beta/openai/"
)

# %%
def evaluate(reply, message, history) -> Evaluation:

    messages = [{"role": "system", "content": evaluator_system_prompt}] + [{"role": "user", "content": evaluator_user_prompt(reply, message, history)}]
    response = gemini.beta.chat.completions.parse(model="gemini-2.0-flash", messages=messages, response_format=Evaluation)
    return response.choices[0].message.parsed

# %%
messages = [{"role": "system", "content": system_prompt}] + [{"role": "user", "content": "Are you an MBA?"}]
response = openai.chat.completions.create(model="gpt-4o-mini", messages=messages)
reply = response.choices[0].message.content

# %%
reply
# Out:
# 'Yes, I hold an MBA with a focus in Operations from the Symbiosis Institute of Business Management. My educational background has provided me with a strong foundation in business processes and management strategies, which I have applied throughout my career in supply chain management and consulting. If you have any further questions or would like to know more about my experience, feel free to ask!'

# %%
evaluate(reply, "do you hold a patent?", messages[:1])
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[64], line 1
# ----> 1 evaluate(reply, "do you hold a patent?", messages[:1])
#
# Cell In[59], line 4, in evaluate(reply, message, history)
#       1 def evaluate(reply, message, history) -> Evaluation:
#       3     messages = [{"role": "system", "content": evaluator_system_prompt}] + [{"role": "user", "content": evaluator_user_prompt(reply, message, history)}]
# ----> 4     response = gemini.beta.chat.completions.parse(model="gemini-2.0-flash", messages=messages, response_format=Evaluation)
#       5     return response.choices[0].message.parsed
#
# File c:\Users\LENOVO\Documents\agent_practice\.venv\Lib\site-packages\openai\resources\chat\completions\completions.py:184, in Completions.parse(self, messages, model, audio, response_format, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, prompt_cache_key, prompt_cache_retention, reasoning_effort, safety_identifier, seed, service_tier, stop, store, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, verbosity, web_search_options, extra_headers, extra_query, extra_body, timeout)
#     177 def parser(raw_completion: ChatCompletion) -> ParsedChatCompletion[ResponseFormatT]:
#     178     return _parse_chat_completion(
#     179         response_format=response_format,
#     180         chat_completion=raw_completion,
#     181         input_tools=chat_completion_tools,
#     182     )
# --> 184 return self._post(
#     185     "/chat/completions",
#     186     body=maybe_transform(
#     187         {
#     188             "messages": messages,
#     189             "model": model,
#     190             "audio": audio,
#     191             "frequency_penalty": frequency_penalty,
#     192             "function_call": function_call,
#     193             "functions": functions,
#     194             "logit_bias": logit_bias,
#     195             "logprobs": logprobs,
#     196             "max_completion_tokens": max_completion_tokens,
#     197             "max_tokens": max_tokens,
#     198             "metadata": metadata,
#     199             "modalities": modalities,
#     200             "n": n,
#     201             "parallel_tool_calls": parallel_tool_calls,
#     202             "prediction": prediction,
#     203             "presence_penalty": presence_penalty,
#     204             "prompt_cache_key": prompt_cache_key,
#     205             "prompt_cache_retention": prompt_cache_retention,
#     206             "reasoning_effort": reasoning_effort,
#     207             "response_format": _type_to_response_format(response_format),
#     208             "safety_identifier": safety_identifier,
#     209             "seed": seed,
#     210             "service_tier": service_tier,
#     211             "stop": stop,
#     212             "store": store,
#     213             "stream": False,
#     214             "stream_options": stream_options,
#     215             "temperature": temperature,
#     216             "tool_choice": tool_choice,
#     217             "tools": tools,
#     218             "top_logprobs": top_logprobs,
#     219             "top_p": top_p,
#     220             "user": user,
#     221             "verbosity": verbosity,
#     222             "web_search_options": web_search_options,
#     223         },
#     224         completion_create_params.CompletionCreateParams,
#     225     ),
#     226     options=make_request_options(
#     227         extra_headers=extra_headers,
#     228         extra_query=extra_query,
#     229         extra_body=extra_body,
#     230         timeout=timeout,
#     231         post_parser=parser,
#     232     ),
#     233     # we turn the `ChatCompletion` instance into a `ParsedChatCompletion`
#     234     # in the `parser` function above
#     235     cast_to=cast(Type[ParsedChatCompletion[ResponseFormatT]], ChatCompletion),
#     236     stream=False,
#     237 )
#
# File c:\Users\LENOVO\Documents\agent_practice\.venv\Lib\site-packages\openai\_base_client.py:1259, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1245 def post(
#    1246     self,
#    1247     path: str,
#    (...)   1254     stream_cls: type[_StreamT] | None = None,
#    1255 ) -> ResponseT | _StreamT:
#    1256     opts = FinalRequestOptions.construct(
#    1257         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1258     )
# -> 1259     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File c:\Users\LENOVO\Documents\agent_practice\.venv\Lib\site-packages\openai\_base_client.py:1047, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1044             err.response.read()
#    1046         log.debug("Re-raising status error")
# -> 1047         raise self._make_status_error_from_response(err.response) from None
#    1049     break
#    1051 assert response is not None, "could not resolve response (should never happen)"
#
# RateLimitError: Error code: 429 - [{'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/usage?tab=rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 0, model: gemini-2.0-flash\n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 0, model: gemini-2.0-flash\n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_input_token_count, limit: 0, model: gemini-2.0-flash\nPlease retry in 33.254473542s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerDayPerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.0-flash'}}, {'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.0-flash'}}, {'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_input_token_count', 'quotaId': 'GenerateContentInputTokensPerModelPerMinute-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.0-flash'}}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '33s'}]}}]
